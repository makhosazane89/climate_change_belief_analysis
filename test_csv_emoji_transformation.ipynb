# %% [markdown]
# <a href="https://colab.research.google.com/github/makhosazane89/climate_change_belief_analysis/blob/master/test_csv_emoji_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string

# %%
df = pd.read_csv("test.csv")
df.head(20)
# Out:
#                                               message  tweetid
# 0   Europe will now be looking to China to make su...   169760
# 1   Combine this with the polling of staffers re c...    35326
# 2   The scary, unimpeachable evidence that climate...   224985
# 3   @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263
# 4   RT @FakeWillMoore: 'Female orgasms cause globa...   872928
# 5   RT @nycjim: Trump muzzles employees of several...    75639
# 6   @bmastenbrook yes wrote that in 3rd yr Comp Sc...   211536
# 7   RT @climatehawk1: Indonesian farmers weather #...   569434
# 8   RT @guardian: British scientists face a ‘huge ...   315368
# 9   Aid For Agriculture | Sustainable agriculture ...   591733
# 10  There is no climate change, Globalists! https:...    91983
# 11  Biggest threat to our economy is climate chang...    67249
# 12  RT @100isNow: He's CEO of a company that lied ...   143459
# 13  RT @VICE: Venice could be swallowed by water w...   663535
# ...

# %%
def emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)
    df['text_rare'] = df['text_rare'].apply(remove_emoji)

# %%
df = pd.read_csv("test.csv")
df.tail(20)
# Out:
#                                                  message  tweetid
# 10526  RT @Complex: .@BillNye on climate change under...    53118
# 10527  @CNNPolitics @cnnbrk taking money from the lit...   402290
# 10528  Tackling climate change doesn’t cost the Earth...   954816
# 10529  RT @ClimateRealists: Three Cheers: Another US ...   285572
# 10530  pnwsocialists: Microbes in soil are essential ...   682172
# 10531  RT @GlennKesslerWP: The Trump administration j...   229711
# 10532  Older politicians that deny climate change are...    17840
# 10533  RT @SteveSGoddard: 'for the last four decades ...   959088
# 10534  RT @ClimateChangeB: Guest Opinion: Time to act...   638708
# 10535  RT @alexwagner: The areas of the US that will ...   940588
# 10536  @SenSanders scientists disagree in means of di...   288271
# 10537  RT @a35362: Scientists explain apocalyptic eff...   961513
# 10538  Just watched Nat Geo's documentary about clima...    46205
# ...

# %%
# !pip install emot --upgrade

# %%
from emot.emo_unicode import UNICODE_EMO, EMOTICONS
# Converting emojis to words
def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = text.replace(emot, "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()))
        return text
# Converting emoticons to words    
def convert_emoticons(text):
    for emot in EMOTICONS:
        text = (u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
        return text

# %%
df.head(20)
# Out:
#                                               message  tweetid
# 0   Europe will now be looking to China to make su...   169760
# 1   Combine this with the polling of staffers re c...    35326
# 2   The scary, unimpeachable evidence that climate...   224985
# 3   @Karoli @morgfair @OsborneInk @dailykos \nPuti...   476263
# 4   RT @FakeWillMoore: 'Female orgasms cause globa...   872928
# 5   RT @nycjim: Trump muzzles employees of several...    75639
# 6   @bmastenbrook yes wrote that in 3rd yr Comp Sc...   211536
# 7   RT @climatehawk1: Indonesian farmers weather #...   569434
# 8   RT @guardian: British scientists face a ‘huge ...   315368
# 9   Aid For Agriculture | Sustainable agriculture ...   591733
# 10  There is no climate change, Globalists! https:...    91983
# 11  Biggest threat to our economy is climate chang...    67249
# 12  RT @100isNow: He's CEO of a company that lied ...   143459
# 13  RT @VICE: Venice could be swallowed by water w...   663535
# ...

# %%
df.tail(20)
# Out:
#                                                  message  tweetid
# 10526  RT @Complex: .@BillNye on climate change under...    53118
# 10527  @CNNPolitics @cnnbrk taking money from the lit...   402290
# 10528  Tackling climate change doesn’t cost the Earth...   954816
# 10529  RT @ClimateRealists: Three Cheers: Another US ...   285572
# 10530  pnwsocialists: Microbes in soil are essential ...   682172
# 10531  RT @GlennKesslerWP: The Trump administration j...   229711
# 10532  Older politicians that deny climate change are...    17840
# 10533  RT @SteveSGoddard: 'for the last four decades ...   959088
# 10534  RT @ClimateChangeB: Guest Opinion: Time to act...   638708
# 10535  RT @alexwagner: The areas of the US that will ...   940588
# 10536  @SenSanders scientists disagree in means of di...   288271
# 10537  RT @a35362: Scientists explain apocalyptic eff...   961513
# 10538  Just watched Nat Geo's documentary about clima...    46205
# ...
